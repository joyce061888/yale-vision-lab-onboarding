# %% [markdown]
# <a href="https://colab.research.google.com/github/joyce061888/yale-vision-lab-onboarding/blob/main/tensorboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab import auth
from google.auth import default
import os

drive.mount('/content/drive/', force_remount=True)
os.chdir('/content/drive/MyDrive/workspace/classification-tutorial')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Launch Tensorboard to visualize logged summary

# %%
# %load_ext tensorboard
# %tensorboard --logdir <path/to/checkpoint/directory>
